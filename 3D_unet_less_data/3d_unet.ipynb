# %%
# load tensorboard extension
# we will need this later in the notebook to monitor the training progress
# %load_ext tensorboard

# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import torch.nn as nn
# import torch_em
# %aimport torch_em
import torch_em.data.datasets as torchem_data
from torch_em.model import AnisotropicUNet
from torch_em.util.debug import check_loader, check_trainer

from pathlib import Path
# Out:
# /g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/bioimageio/spec/shared/_resolve_source.py:377: UserWarning: found cached /tmp/bioimageio_cache/https/raw.githubusercontent.com/bioimage-io/bioimage.io/main/site.config.json. Skipping download of https://raw.githubusercontent.com/bioimage-io/bioimage.io/main/site.config.json.
#   warnings.warn(f"found cached {local_path}. Skipping download of {uri}.")
# /g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/bioimageio/spec/shared/_resolve_source.py:377: UserWarning: found cached /tmp/bioimageio_cache/https/bioimage-io.github.io/collection-bioimage-io/collection.json. Skipping download of https://bioimage-io.github.io/collection-bioimage-io/collection.json.
#   warnings.warn(f"found cached {local_path}. Skipping download of {uri}.")

# %% [markdown]
# # Training data

# %%
train_data_paths = "/scratch/buglakova/F107_bin2_619-639_predictions/full_raw.n5"
data_key = "raw/raw_data"
train_label_paths = "/scratch/buglakova/3D_UNet_data/ground_truth_labels_CZXY.n5"
label_key = "labels/out_boundary_extra_fg"

# In addition you can also specify region of interests for training using the normal python slice syntax
train_rois = np.s_[594:650, :, :]
val_rois = np.s_[540:594, :, :]

#
# choose the patch shape
#
patch_shape = (32, 512, 512)

# %%
def check_data(data_paths, label_paths, rois):
    print("Loading the raw data from:", data_paths, data_key)
    print("Loading the labels from:", label_paths, label_key)
    try:
        torch_em.default_segmentation_dataset(data_paths, data_key, label_paths, label_key, patch_shape, rois=rois, with_label_channels=True)
    except Exception as e:
        print("Loading the dataset failed with:")
        raise e

print("Checking the training dataset:")
check_data(train_data_paths, train_label_paths, train_rois)
check_data(train_data_paths, train_label_paths, val_rois)

assert len(patch_shape) == 3
# Out:
# Checking the training dataset:
# Loading the raw data from: /scratch/buglakova/F107_bin2_619-639_predictions/full_raw.n5 raw/raw_data
# Loading the labels from: /scratch/buglakova/3D_UNet_data/ground_truth_labels_CZXY.n5 labels/out_boundary_extra_fg
# Loading the raw data from: /scratch/buglakova/F107_bin2_619-639_predictions/full_raw.n5 raw/raw_data
# Loading the labels from: /scratch/buglakova/3D_UNet_data/ground_truth_labels_CZXY.n5 labels/out_boundary_extra_fg

# %% [markdown]
# # Loss, metric & batch size

# %%
batch_size = 1
loss = "dice"
metric = "dice"

# %%
def get_loss(loss_name, loss_transform=None):
    loss_names = ["bce", "ce", "dice"]
    if isinstance(loss_name, str):
        assert loss_name in loss_names, f"{loss_name}, {loss_names}"
        if loss_name == "dice":
            loss_function = torch_em.loss.DiceLoss()
        elif loss == "ce":
            loss_function = nn.CrossEntropyLoss()
        elif loss == "bce":
            loss_function = nn.BCEWithLogitsLoss()
    else:
        loss_function = loss_name
    
    # we need to add a loss wrapper for affinities
    if loss_transform:
        loss_function = torch_em.loss.LossWrapper(
            loss_function, transform=loss_transform
        )
    return loss_function

# %%
class ApplyMask:
    def __call__(self, prediction, target, mask_const=-1):
        assert target.dim() == prediction.dim(), f"{target.dim()}, {prediction.dim()}"
        assert target.shape[2:] == prediction.shape[2:], f"{str(target.shape)}, {str(prediction.shape)}"

        mask = target != mask_const
        mask.requires_grad = False

        # mask the prediction
        prediction = prediction * mask
        # print("Prediction range", prediction.min(), prediction.max())
        
        target = target * mask
        # print("Target range", target.min(), target.max())

        # with open("metrics.txt", "a") as f:
        #     f.write("pred " + str(prediction.min()) + str(prediction.max()))
        #     f.write(r"/n target " + str(target.min()) + str(target.max()))
        return prediction, target

# %%
loss_function = get_loss(loss)
metric_function = get_loss(metric, loss_transform=ApplyMask())

kwargs = dict(
    ndim=3, patch_shape=patch_shape, batch_size=batch_size, with_label_channels=True
)

train_loader = torch_em.default_segmentation_loader(
    train_data_paths, data_key, train_label_paths, label_key,
    rois=train_rois, **kwargs
)
val_loader = torch_em.default_segmentation_loader(
    train_data_paths, data_key, train_label_paths, label_key,
    rois=val_rois, **kwargs
)

# %%
for i, img in zip(range(3), train_loader):
    print(i, img[1].shape)
# Out:
# 0 torch.Size([1, 4, 32, 256, 512])
# 1 torch.Size([1, 4, 32, 256, 512])
# 2 torch.Size([1, 4, 32, 256, 512])

# %%
import torch
from torch_em.loss import (ApplyAndRemoveMask,
                                   DiceLoss,
                                   LossWrapper)
loss = LossWrapper(DiceLoss(),
                    transform=ApplyAndRemoveMask())

shape = (1, 1, 128, 128)
x = torch.rand(*shape)
x.requires_grad = True
x.retain_grad = True

y = torch.rand(*shape)
y_pred = y
mask = torch.rand(*shape) > .5
mask = torch.ones_like(y)
y = torch.cat([
    y, mask.to(dtype=y.dtype)
], dim=1)

lval = loss(x, y)
print(loss(y_pred, y))
print(loss(x, x))
print(0. < lval.item() < 1.)
lval.backward()

grad = x.grad.numpy()
mask = mask.numpy()
# print((grad[mask] == 0).sum())
print((grad[mask] == 0).all())
# print((grad[~mask] == 0).sum())
print((grad[~mask] == 0).all())
# Out:
# tensor(0.)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /g/kreshuk/buglakova/fibsem_segm/3D_unet/3d_unet.ipynb Cell 13' in <module>
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu6.cluster.embl.de/g/kreshuk/buglakova/fibsem_segm/3D_unet/3d_unet.ipynb#ch0000024vscode-remote?line=20'>21</a> lval = loss(x, y)
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu6.cluster.embl.de/g/kreshuk/buglakova/fibsem_segm/3D_unet/3d_unet.ipynb#ch0000024vscode-remote?line=21'>22</a> print(loss(y_pred, y))
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bgpu6.cluster.embl.de/g/kreshuk/buglakova/fibsem_segm/3D_unet/3d_unet.ipynb#ch0000024vscode-remote?line=22'>23</a> print(loss(x, x))
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu6.cluster.embl.de/g/kreshuk/buglakova/fibsem_segm/3D_unet/3d_unet.ipynb#ch0000024vscode-remote?line=23'>24</a> print(0. < lval.item() < 1.)
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu6.cluster.embl.de/g/kreshuk/buglakova/fibsem_segm/3D_unet/3d_unet.ipynb#ch0000024vscode-remote?line=24'>25</a> lval.backward()
#
# File /g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1097'>1098</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1098'>1099</a> # this function, and just call forward.
#    <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1099'>1100</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1100'>1101</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1101'>1102</a>     return forward_call(*input, **kwargs)
#    <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1102'>1103</a> # Do not call functions when jit is used
#    <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1103'>1104</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# File /g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py:35, in LossWrapper.forward(self, prediction, target)
#      <a href='file:///g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py?line=33'>34</a> def forward(self, prediction, target):
# ---> <a href='file:///g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py?line=34'>35</a>     prediction, target = self.apply_transform(prediction, target)
#      <a href='file:///g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py?line=35'>36</a>     loss = self.loss(prediction, target)
#      <a href='file:///g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py?line=36'>37</a>     return loss
#
# File /g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py:31, in LossWrapper.apply_transform(self, prediction, target)
#      <a href='file:///g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py?line=27'>28</a>     return transformed_prediction, transformed_target
#      <a href='file:///g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py?line=28'>29</a> # tensor input
#      <a href='file:///g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py?line=29'>30</a> else:
# ---> <a href='file:///g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py?line=30'>31</a>     prediction, target = self.transform(prediction, target)
#      <a href='file:///g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py?line=31'>32</a>     return prediction, target
#
# File /g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py:47, in ApplyAndRemoveMask.__call__(self, prediction, target)
#      <a href='file:///g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py?line=44'>45</a> def __call__(self, prediction, target):
#      <a href='file:///g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py?line=45'>46</a>     assert target.dim() == prediction.dim(), f"{target.dim()}, {prediction.dim()}"
# ---> <a href='file:///g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py?line=46'>47</a>     assert target.size(1) == 2 * prediction.size(1), f"{target.size(1)}, {prediction.size(1)}"
#      <a href='file:///g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py?line=47'>48</a>     assert target.shape[2:] == prediction.shape[2:], f"{str(target.shape)}, {str(prediction.shape)}"
#      <a href='file:///g/kreshuk/buglakova/libraries/torch-em/torch_em/loss/wrapper.py?line=49'>50</a>     seperating_channel = target.size(1) // 2
#
# AssertionError: 1, 1

# %%
print(x).shape
# Out:
# tensor([[[[0.0958, 0.9040, 0.4399,  ..., 0.2314, 0.4139, 0.9259],
#           [0.8489, 0.0678, 0.0469,  ..., 0.9470, 0.1638, 0.3229],
#           [0.5618, 0.1698, 0.2339,  ..., 0.4351, 0.5806, 0.7395],
#           ...,
#           [0.7911, 0.7290, 0.5211,  ..., 0.9830, 0.0073, 0.6277],
#           [0.6422, 0.1994, 0.6191,  ..., 0.6566, 0.3093, 0.1511],
#           [0.3977, 0.6870, 0.9941,  ..., 0.8223, 0.7560, 0.9360]]]],
#        requires_grad=True)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /g/kreshuk/buglakova/fibsem_segm/3D_unet/3d_unet.ipynb Cell 14' in <module>
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bgpu6.cluster.embl.de/g/kreshuk/buglakova/fibsem_segm/3D_unet/3d_unet.ipynb#ch0000026vscode-remote?line=0'>1</a> print(x).shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# # Check training data

# %%
n_samples = 2
use_napari = False

print("Training samples")
check_loader(train_loader, n_samples, plt=not use_napari)
print("Validation samples")
check_loader(val_loader, n_samples, plt=not use_napari)
# Out:
# Training samples
# Label shape: (4, 32, 256, 512)
# Number of annotated pixels: 4718592 out of 16777216
# Number of annotated slices: 4718592 out of 16777216
# 3D data, showing slices at (256, 128, 16) out of (1, 32, 256, 512)
# Label shape: (4, 32, 256, 512)
# Number of annotated pixels: 4718592 out of 16777216
# Number of annotated slices: 4718592 out of 16777216
# 3D data, showing slices at (256, 128, 16) out of (1, 32, 256, 512)
# Validation samples
# Label shape: (4, 32, 256, 512)
# Number of annotated pixels: 524288 out of 16777216
# Number of annotated slices: 524288 out of 16777216
# 3D data, showing slices at (256, 128, 16) out of (1, 32, 256, 512)
# Label shape: (4, 32, 256, 512)
# Number of annotated pixels: 524288 out of 16777216
# Number of annotated slices: 524288 out of 16777216
# 3D data, showing slices at (256, 128, 16) out of (1, 32, 256, 512)

# %% [markdown]
# # Network architecture

# %% [markdown]
# Choose the important network architecture parameters for the 2d UNet:
#
#    - `scale_factors`: the down/upscaling factors between each encoder/decoder level. This is specified as a list of 3d scale factors, which enables anisotropic scaling. See the example in the comments for details.
#    - `initial_features`: the number of features in the first encoder level, the number will be doubled for each level
#    - `final_activation`: the activation applied to the UNet output
#    - `in_channels`: the number of input channels (= number of channels of the raw data)
#    - `out_channels`: the number of output channels (usually the number of target channels)

# %%
# example for 4 levels with anisotropic scaling in the first two levels (scale only in xy)
scale_factors = [[1, 2, 2], [1, 2, 2], [2, 2, 2], [2, 2, 2]]

initial_features = 32
final_activation = "Sigmoid"

in_channels = 1
out_channels = 4

# %%
print("Creating 3d UNet with", in_channels, "input channels and", out_channels, "output channels.")
model = AnisotropicUNet(
    in_channels=in_channels, out_channels=out_channels, scale_factors=scale_factors, final_activation=final_activation
)
# Out:
# Creating 3d UNet with 1 input channels and 4 output channels.

# %% [markdown]
# # Tensorboard

# %%
# %tensorboard --logdir logs
# Out:
# Reusing TensorBoard on port 6006 (pid 140541), started 0:26:29 ago. (Use '!kill 140541' to kill it.)
#       <iframe id="tensorboard-frame-bdd4417252631b5f" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-bdd4417252631b5f");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # Training

# %%
experiment_name = "default_network"
n_iterations = 10000
learning_rate = 1.0e-4

# %%
trainer = torch_em.default_segmentation_trainer(
    name=experiment_name, model=model,
    train_loader=train_loader, val_loader=val_loader,
    loss=loss_function, metric=metric_function,
    learning_rate=learning_rate,
    mixed_precision=True,
    log_image_interval=50
)
trainer.fit(n_iterations)
# Out:
# Start fitting for 10000 iterations /  118 epochs
# Training with mixed precision
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /g/kreshuk/buglakova/fibsem_segm/3D_unet/3d_unet.ipynb Cell 22' in <module>
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu6.cluster.embl.de/g/kreshuk/buglakova/fibsem_segm/3D_unet/3d_unet.ipynb#ch0000032vscode-remote?line=0'>1</a> trainer = torch_em.default_segmentation_trainer(
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu6.cluster.embl.de/g/kreshuk/buglakova/fibsem_segm/3D_unet/3d_unet.ipynb#ch0000032vscode-remote?line=1'>2</a>     name=experiment_name, model=model,
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu6.cluster.embl.de/g/kreshuk/buglakova/fibsem_segm/3D_unet/3d_unet.ipynb#ch0000032vscode-remote?line=2'>3</a>     train_loader=train_loader, val_loader=val_loader,
#    (...)
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu6.cluster.embl.de/g/kreshuk/buglakova/fibsem_segm/3D_unet/3d_unet.ipynb#ch0000032vscode-remote?line=6'>7</a>     log_image_interval=50
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu6.cluster.embl.de/g/kreshuk/buglakova/fibsem_segm/3D_unet/3d_unet.ipynb#ch0000032vscode-remote?line=7'>8</a> )
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bgpu6.cluster.embl.de/g/kreshuk/buglakova/fibsem_segm/3D_unet/3d_unet.ipynb#ch0000032vscode-remote?line=8'>9</a> trainer.fit(n_iterations)
#
# File /g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/trainer/default_trainer.py:279, in DefaultTrainer.fit(self, iterations, load_from_checkpoint)
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/trainer/default_trainer.py?line=276'>277</a> for _ in range(train_epochs):
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/trainer/default_trainer.py?line=277'>278</a>     t_per_iter = train_epoch(progress)
# --> <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/trainer/default_trainer.py?line=278'>279</a>     current_metric = validate()
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/trainer/default_trainer.py?line=280'>281</a>     if self.lr_scheduler is not None:
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/trainer/default_trainer.py?line=281'>282</a>         self.lr_scheduler.step(current_metric)
#
# File /g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/trainer/default_trainer.py:403, in DefaultTrainer._validate_mixed(self)
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/trainer/default_trainer.py?line=399'>400</a> loss_val = 0.0
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/trainer/default_trainer.py?line=401'>402</a> with torch.no_grad():
# --> <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/trainer/default_trainer.py?line=402'>403</a>     for x, y in self.val_loader:
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/trainer/default_trainer.py?line=403'>404</a>         x, y = x.to(self.device), y.to(self.device)
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/trainer/default_trainer.py?line=404'>405</a>         with amp.autocast():
#
# File /g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/dataloader.py:521, in _BaseDataLoaderIter.__next__(self)
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=518'>519</a> if self._sampler_iter is None:
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=519'>520</a>     self._reset()
# --> <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=520'>521</a> data = self._next_data()
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=521'>522</a> self._num_yielded += 1
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=522'>523</a> if self._dataset_kind == _DatasetKind.Iterable and \
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=523'>524</a>         self._IterableDataset_len_called is not None and \
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=524'>525</a>         self._num_yielded > self._IterableDataset_len_called:
#
# File /g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/dataloader.py:561, in _SingleProcessDataLoaderIter._next_data(self)
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=558'>559</a> def _next_data(self):
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=559'>560</a>     index = self._next_index()  # may raise StopIteration
# --> <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=560'>561</a>     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=561'>562</a>     if self._pin_memory:
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=562'>563</a>         data = _utils.pin_memory.pin_memory(data)
#
# File /g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:49, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=46'>47</a> def fetch(self, possibly_batched_index):
#      <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=47'>48</a>     if self.auto_collation:
# ---> <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=48'>49</a>         data = [self.dataset[idx] for idx in possibly_batched_index]
#      <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=49'>50</a>     else:
#      <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=50'>51</a>         data = self.dataset[possibly_batched_index]
#
# File /g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:49, in <listcomp>(.0)
#      <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=46'>47</a> def fetch(self, possibly_batched_index):
#      <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=47'>48</a>     if self.auto_collation:
# ---> <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=48'>49</a>         data = [self.dataset[idx] for idx in possibly_batched_index]
#      <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=49'>50</a>     else:
#      <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=50'>51</a>         data = self.dataset[possibly_batched_index]
#
# File /g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/data/segmentation_dataset.py:142, in SegmentationDataset.__getitem__(self, index)
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/data/segmentation_dataset.py?line=140'>141</a> def __getitem__(self, index):
# --> <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/data/segmentation_dataset.py?line=141'>142</a>     raw, labels = self._get_sample(index)
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/data/segmentation_dataset.py?line=142'>143</a>     initial_label_dtype = labels.dtype
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/data/segmentation_dataset.py?line=144'>145</a>     if self.raw_transform is not None:
#
# File /g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/data/segmentation_dataset.py:115, in SegmentationDataset._get_sample(self, index)
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/data/segmentation_dataset.py?line=112'>113</a> bb_raw = (slice(None),) + bb if self._with_channels else bb
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/data/segmentation_dataset.py?line=113'>114</a> bb_labels = (slice(None),) + bb if self._with_label_channels else bb
# --> <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/data/segmentation_dataset.py?line=114'>115</a> raw, labels = self.raw[bb_raw], self.labels[bb_labels]
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/data/segmentation_dataset.py?line=116'>117</a> if self.sampler is not None:
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/torch_em/data/segmentation_dataset.py?line=117'>118</a>     sample_id = 0
#
# File /g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/elf/wrapper/generic.py:63, in RoiWrapper.__getitem__(self, index)
#      <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/elf/wrapper/generic.py?line=60'>61</a> index, to_squeeze = normalize_index(index, self.shape)
#      <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/elf/wrapper/generic.py?line=61'>62</a> index = self.map_index_to_volume(index)
# ---> <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/elf/wrapper/generic.py?line=62'>63</a> out = self._volume[index]
#      <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/elf/wrapper/generic.py?line=63'>64</a> return squeeze_singletons(out, to_squeeze)
#
# File /g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/z5py/dataset.py:363, in Dataset.__getitem__(self, index)
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/z5py/dataset.py?line=360'>361</a> out = np.empty(shape, dtype=self.dtype)
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/z5py/dataset.py?line=361'>362</a> if 0 not in shape:
# --> <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/z5py/dataset.py?line=362'>363</a>     _z5py.read_subarray(self._impl,
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/z5py/dataset.py?line=363'>364</a>                         out, roi_begin,
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/z5py/dataset.py?line=364'>365</a>                         n_threads=self.n_threads)
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/z5py/dataset.py?line=366'>367</a> # todo: this probably has more copies than necessary
#     <a href='file:///g/kreshuk/buglakova/anaconda3/envs/dl-image-pytorch-gpu/lib/python3.9/site-packages/z5py/dataset.py?line=367'>368</a> if len(to_squeeze) == len(shape):
#
# KeyboardInterrupt:
# Epoch 0:   1%|          | 85/10000 [22:21<43:27:08, 15.78s/it]
