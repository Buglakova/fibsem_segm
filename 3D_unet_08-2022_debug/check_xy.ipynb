# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import napari

# %%
save_path = "/scratch/buglakova/data/train_xy_dump"

n_iter = 142
x = np.load(os.path.join(save_path, str(n_iter) + "_x.npy"))
y = np.load(os.path.join(save_path, str(n_iter) + "_y.npy"))

# %%
x.shape
# Out:
# (1, 1, 64, 128, 128)

# %%
y.shape
# Out:
# (1, 4, 64, 128, 128)

# %%
plt.imshow(x[0, 0, :, 64, :])

# %%
x.max()
# Out:
# 1.0

# %%
plt.imshow(y[0, 3, :, 64, :])

# %%
y.min()
# Out:
# -1.0

# %%
v = napari.Viewer()
# Out:
# WARNING: QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-buglakov'

# %%
v.add_image(x[0, 0 , : ,:, :])
# Out:
# <Image layer 'Image' at 0x7f51d87077c0>

# %%
v.add_image(y[0, 0, : ,:, :])
v.add_image(y[0, 1, : ,:, :])
v.add_image(y[0, 2, : ,:, :])
# Out:
# <Image layer 'Image [3]' at 0x7f51c8149ae0>

# %%
v.add_image(y[0, 2, : ,:, :])
# Out:
# <Image layer 'Image [2]' at 0x7f51f43b48e0>
